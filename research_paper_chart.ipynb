# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
days = [4,5,1,6,2,6,4,6,4,4,3,1,1,3,6,1,3,4,5,6,5,4,1,1,1,2,3,1,3,4,7]
height = [1.83,1.60,1.79,1.82,1.73,1.68,1.71,1.75,1.78,1.53,1.56,
          1.72,1.75,1.55,1.62,1.65,1.73,1.52,1.68,1.56,1.80,1.83,1.88,
          1.80,1.77,1.70,1.70,1.8,1.7,1.65,2.00]
uncertainty = [0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.02,0.02,0.02,0.02,
               0.005,0.005,0.005,0.005,0.005,0.005,0.01,0.01,0.01,0.001,
               0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001]

# %%
len(days), len(height), len(uncertainty)
# Out:
# (31, 31, 31)

# %%
#plt.scatter(days, height)
plt.errorbar(days, height, yerr=uncertainty, fmt='o', capsize=5)
plt.xlabel('Day of the Week (1=Monday, ..., 7=Sunday)')
plt.ylabel('Height (m)')
plt.title('Day of the Week vs Height (m)')
plt.savefig('myimage.pdf')
